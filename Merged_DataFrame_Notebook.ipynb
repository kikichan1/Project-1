# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# File to Load
drug_deaths_to_load = Path('Data/opioid_death_counts.csv')
employment_data_to_load = Path('Data/combined_employment_data.csv')

# # Read Drug Overdose Data File and store into Pandas DataFrames
opioid_csv = pd.read_csv(drug_deaths_to_load)
employment_csv = pd.read_csv(employment_data_to_load)

# %%
opioid_csv
# Out:
#      Year            State Name                    Indicator  \
# 0    2017                Alaska  Opioids (T40.0-T40.4,T40.6)
# 1    2017               Arizona  Opioids (T40.0-T40.4,T40.6)
# 2    2017           Connecticut  Opioids (T40.0-T40.4,T40.6)
# 3    2017  District of Columbia  Opioids (T40.0-T40.4,T40.6)
# 4    2017               Georgia  Opioids (T40.0-T40.4,T40.6)
# ..    ...                   ...                          ...
# 193  2022              Virginia  Opioids (T40.0-T40.4,T40.6)
# 194  2022            Washington  Opioids (T40.0-T40.4,T40.6)
# 195  2022         West Virginia  Opioids (T40.0-T40.4,T40.6)
# 196  2022             Wisconsin  Opioids (T40.0-T40.4,T40.6)
# 197  2022               Wyoming  Opioids (T40.0-T40.4,T40.6)
#
#      Total_Opioid_Deaths
# 0                    100
# 1                    936
# 2                    967
# 3                    271
# 4                   1003
# ..                   ...
# 193                 2108
# 194                 2101
# 195                 1139
# 196                 1421
# 197                   79
#
# [198 rows x 4 columns]

# %%
employment_csv
# Out:
#      Unnamed: 0  Year          State  State ID    Geography  \
# 0             0  2022        Alabama         1  0400000US01
# 1             1  2022         Alaska         2  0400000US02
# 2             2  2022        Arizona         4  0400000US04
# 3             3  2022       Arkansas         5  0400000US05
# 4             4  2022     California         6  0400000US06
# ..          ...   ...            ...       ...          ...
# 250         250  2017          Maine        23  0400000US23
# 251         251  2017       Maryland        24  0400000US24
# 252         252  2017  Massachusetts        25  0400000US25
# 253         253  2017       Michigan        26  0400000US26
# 254         254  2017      Minnesota        27  0400000US27
#
#      Total Eligible for Employment  Total in Labor Force  \
# 0                          4093740               2398213
# 1                           575934                386093
# 2                          5961733               3619698
# 3                          2430600               1404190
# 4                         31552708              20174168
# ..                             ...                   ...
# 250                        1114189                702420
# 251                        4855374               3294443
# 252                        5660731               3776331
# 253                        8052502               4949724
# 254                        4422835               3073117
#
#      Total Not in Labor Force  Total in Civilian Labor Force  \
# 0                     1695527                        2381733
# 1                      189841                         361685
# 2                     2342035                        3595613
# 3                     1026410                        1397919
# 4                    11378540                       20003799
# ..                        ...                            ...
# 250                    411769                         700979
# 251                   1560931                        3268601
# 252                   1884400                        3771625
# 253                   3102778                        4945632
# 254                   1349718                        3070881
#
#      Total Employed in Civilian Labor Force  \
# 0                                   2278494
# 1                                    345201
# 2                                   3441676
# 3                                   1335560
# 4                                  18942977
# ..                                      ...
# 250                                  671486
# 251                                 3098182
# 252                                 3599534
# 253                                 4654612
# 254                                 2960124
#
#      Total Unemployed in Civilian Labor Force  Total in Armed Labor Force
# 0                                      103239                       16480
# 1                                       16484                       24408
# 2                                      153937                       24085
# 3                                       62359                        6271
# 4                                     1060822                      170369
# ..                                        ...                         ...
# 250                                     29493                        1441
# 251                                    170419                       25842
# 252                                    172091                        4706
# 253                                    291020                        4092
# 254                                    110757                        2236
#
# [255 rows x 12 columns]
